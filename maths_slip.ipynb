# %%
from pylab import*
import numpy as np
import matplotlib.pyplot as plt
from math import*
from sympy import*
from mpl_toolkits.mplot3d import*

# %%
Slip1

# %%
#1)
import matplotlib.pyplot as plt
subjects = ["Math", "English", "Biology", "Physics", "Chemistry"]
marks = [68, 45, 79, 56, 70]
plt.bar(subjects, marks, color='brown')
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("Marks in Different Subjects")
plt.show()

# %%
#2
x = np.linspace(-10, 10, 100)
y = x**3+10*x-5
plt.figure(figsize=(5,3))
plt.plot(x, y, 'r--')
plt.show()

# %%
#3)
def f(x,y):
    return x**2+y**2
x = np.linspace(10, -10, 100)
y = np.linspace(10, -10, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)
ax = plt.axes(projection = '3d')
ax.plot_surface(X, Y, Z, color='pink')
plt.show()

# %%
#4)
P = Point(7, 2)
Q = Point(1, 8)
L = Line(P, Q)
P.distance(Q)
# Out:
# 6*sqrt(2)

# %%
L.slope
# Out:
# -1

# %%
L.equation()
# Out:
# -6*x - 6*y + 54

# %%
#5)
A = Point(2, 2)
B = Point(4, 2)
C = Point(3, 6)
T = Triangle(A, B, C)
T
# Out:
# Triangle(Point2D(2, 2), Point2D(4, 2), Point2D(3, 6))

# %%
T.centroid
# Out:
# Point2D(3, 10/3)

# %%
T.translate(2, 0)
# Out:
# Triangle(Point2D(4, 2), Point2D(6, 2), Point2D(5, 6))

# %%
A1 = A.transform(Matrix([[1, 0, 2], [0, 1, 0],[0, 0, 1]]))
B1 = B.transform(Matrix([[1, 0, 2], [0, 1, 0],[0, 0, 1]]))
C1 = C.transform(Matrix([[1, 0, 2], [0, 1, 0],[0, 0, 1]]))
print(A1, B1, C1)
# Out:
# Point2D(2, 2) Point2D(4, 2) Point2D(3, 6)

# %%
#Q2
A = Point(4, 3)
B = Point(6, 3)
C = Point(6, 5)
D = Point(4, 5)
A1 = A.transform(Matrix([[1, 0, 0], [0, -1, 0], [0, 0, 1]]))
B1 = B.transform(Matrix([[1, 0, 0], [0, -1, 0], [0, 0, 1]]))
C1 = C.transform(Matrix([[1, 0, 0], [0, -1, 0], [0, 0, 1]]))
D1 = D.transform(Matrix([[1, 0, 0], [0, -1, 0], [0, 0, 1]]))
print("The Line of reflection through x axis :",A1, B1, C1, D1)
A2 = A.transform(Matrix([[-1, 0, 0], [0, 1, 0], [0, 0, 1]]))
B2 = B.transform(Matrix([[-1, 0, 0], [0, 1, 0], [0, 0, 1]]))
C2 = C.transform(Matrix([[-1, 0, 0], [0, 1, 0], [0, 0, 1]]))
D2 = D.transform(Matrix([[-1, 0, 0], [0, 1, 0], [0, 0, 1]]))
print("The Line of reflection through y axis :",A2, B2, C2, D2)
# Out:
# The Line of reflection through x axis : Point2D(4, -3) Point2D(6, -3) Point2D(6, -5) Point2D(4, -5)
# The Line of reflection through y axis : Point2D(-4, 3) Point2D(-6, 3) Point2D(-6, 5) Point2D(-4, 5)

# %%
x = [4, 6, 6, 4, 4]
y = [-3, -3, -5, -5, -3]
plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axvline(0, color='black')
plt.axhline(0, color='black')
grid(True)
plt.show()

# %%
r = float(input("Enter radius of circle"))
n = int(input("Enter No of points on circle"))
for i in range(n):
    theta = (2*np.pi*i)/n
    x=r*np.cos(theta)
    y=r*np.sin(theta)
    print(f"Point {i+1}:({x:.4f},{y:.4f})")
# Out:
# Enter radius of circle 5
# Enter No of points on circle 80
# Point 1:(5.0000,0.0000)
# Point 2:(4.9846,0.3923)
# Point 3:(4.9384,0.7822)
# Point 4:(4.8618,1.1672)
# Point 5:(4.7553,1.5451)
# Point 6:(4.6194,1.9134)
# Point 7:(4.4550,2.2700)
# Point 8:(4.2632,2.6125)
# Point 9:(4.0451,2.9389)
# Point 10:(3.8020,3.2472)
# Point 11:(3.5355,3.5355)
# Point 12:(3.2472,3.8020)
# Point 13:(2.9389,4.0451)
# Point 14:(2.6125,4.2632)
# Point 15:(2.2700,4.4550)
# Point 16:(1.9134,4.6194)
# Point 17:(1.5451,4.7553)
# Point 18:(1.1672,4.8618)
# Point 19:(0.7822,4.9384)
# Point 20:(0.3923,4.9846)
# Point 21:(0.0000,5.0000)
# Point 22:(-0.3923,4.9846)
# Point 23:(-0.7822,4.9384)
# Point 24:(-1.1672,4.8618)
# Point 25:(-1.5451,4.7553)
# Point 26:(-1.9134,4.6194)
# Point 27:(-2.2700,4.4550)
# Point 28:(-2.6125,4.2632)
# Point 29:(-2.9389,4.0451)
# Point 30:(-3.2472,3.8020)
# Point 31:(-3.5355,3.5355)
# Point 32:(-3.8020,3.2472)
# Point 33:(-4.0451,2.9389)
# Point 34:(-4.2632,2.6125)
# ...

# %% [markdown]
# slip 2

# %%
import matplotlib.pyplot as plt

sports = ["Cricket", "Football", "Badminton", "Hockey", "Other"]
students = [34, 50, 24, 10, 82]

plt.pie(students, labels=sports, autopct='%1.1f%%')
plt.title("Sports Participation")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
y = x**2 + 5

plt.plot(x, y, 'g--')  # green dashed line
plt.title("Graph of y = x^2 + 5")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-20, 20, 50)
y = np.linspace(-20, 20, 50)

X, Y = np.meshgrid(x, y)
Z = X**2 - Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(X, Y, Z, color='brown')

plt.title("Wireframe Plot")
plt.show()

# %%
from sympy import Point, Matrix

P = Point(-4, 5)

# a) Scaling in x by factor 2
P1 = P.transform(Matrix([[2, 0, 0], [0, 1, 0], [0, 0, 1]]))

# b) Reflection through line y = x
P2 = P.transform(Matrix([[0, 1, 0], [1, 0, 0], [0, 0, 1]]))

# c) Translation in y by +7
P3 = P.transform(Matrix([[1, 0, 0], [0, 1, 7], [0, 0, 1]]))

print("Scaling (x2):", P1)
print("Reflection (y=x):", P2)
print("Translation (+7 in y):", P3)
# Out:
# Scaling (x2): Point2D(-8, 5)
# Reflection (y=x): Point2D(5, -4)
# Translation (+7 in y): Point2D(-4, 5)

# %%
from sympy import Point, Triangle

A = Point(3, 0)
B = Point(0, 4)
C = Point(-3, 0)

t = Triangle(A, B, C)

print("Area:", t.area)
print("Perimeter:", t.perimeter)
print("Angles:", t.angles)
# Out:
# Area: 12
# Perimeter: 16
# Angles: {Point2D(-3, 0): acos(3/5), Point2D(3, 0): acos(3/5), Point2D(0, 4): acos(7/25)}

# %%
# Q2
import matplotlib.pyplot as plt
import numpy as np

# Original points
points = np.array([[1,1], [-5,1], [-5,-4], [1,-4], [1,1]])

# Rotation 90° (about origin)
rotation = np.array([[0, -1], [1, 0]])
rotated = np.dot(points, rotation)

# Shearing (x-direction, factor = 3)
shear = np.array([[1, 3], [0, 1]])
sheared = np.dot(points, shear)

# Plot
plt.plot(points[:,0], points[:,1], label="Original")
plt.plot(rotated[:,0], rotated[:,1], label="Rotated 90°")
plt.plot(sheared[:,0], sheared[:,1], label="Sheared")

plt.legend()
plt.title("Polygon Transformations")
grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sympy import*
import numpy as np
from math import*
from pylab import*
from sympy import Point, Polygon

# %%
#slip 4
#Q1) 1
#slip 4
x = np.linspace(-5, 5, 100)
y = x**3
plt.subplot(2, 1, 1)
plt.plot(x, y, 'r--')
x1 = np.linspace(1, 10, 100)
y1 = np.exp(x1)
plt.subplot(2, 1, 2)
plt.plot(x1, y1)
plt.show()

# %%
#1) 2
x = np.linspace(1, 20, 100)
y = 2*x+5
plt.plot(x, y, color = 'skyblue', linestyle='--')
plt.xlabel('X -axis')
plt.ylabel('Y -axis')
plt.axvline(0, color='black')
plt.axhline(0, color='black')
grid(True)
plt.show()

# %%
def f(x, y):
    return (np.sin(np.sqrt(x**2+y**2)))
x = np.linspace(0, 2*np.pi, 100)
y = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(x, y)
Z = f(X, Y)
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z)
plt.xlabel('X -axis')
plt.ylabel('Y -axis')
plt.show()

# %%
p = Point(1, 1)
q = Point(1, 2)
r = Point(2, 2)
s = Point(2, 1)
square = Polygon(p, q, r, s)
print(square)
print('Area :',square.area)
print('Perimeter :', square.perimeter)
print('Centroid :',square.centroid)
# Out:
# Polygon(Point2D(1, 1), Point2D(1, 2), Point2D(2, 2), Point2D(2, 1))
# Area : -1
# Perimeter : 4
# Centroid : Point2D(3/2, 3/2)

# %%
P = Point3D(2, -1, 3)
T = P.rotate(radians(90))
T
# Out:
# Point3D(2, -1, 3)

# %%
from sympy import Point3D, Matrix

P = Point3D(2, -1, 3)

# Rotation matrix about Z-axis (90°)
R = Matrix([[0, -1, 0],
            [1,  0, 0],
            [0,  0, 1]])

P1 = R * Matrix(P)

print("Rotated Point:", P1)
# Out:
# Rotated Point: Matrix([[1], [2], [3]])

# %%
a = Point(2, 2)
b = Point(5, 7)
L = Line(a, b)
L
# Out:
# Line2D(Point2D(2, 2), Point2D(5, 7))

# %%
a.midpoint(b)
# Out:
# Point2D(7/2, 9/2)

# %%
L = Point(2, 6)
M = Point(-2, 9)
N = Point(-3, -5)
Point.is_collinear(L, M, N)
# Out:
# False

# %%
L = Line(L, M)
L.slope
# Out:
# -3/4

# %%
x = np.linspace(-10, 10)
y= np.sin(x**2)
plt.subplot(2, 1, 1)
plt.plot(x, y)
x1 = np.linspace(-10, np.pi)
y1 = np.cos(x**2)
plt.subplot(2, 1, 2)
plt.plot(x1, y1)
plt.show()

# %%
# Histograph
import matplotlib.pyplot as plt

marks = [71,29,35,21,66,32,24,27,38,44,51,42,49,86,94,46,57,47,41,50,46]

bins = [20,40,60,80,100]

plt.hist(marks, bins=bins, color='brown', edgecolor='black')
plt.xlabel("Marks Range")
plt.ylabel("Number of Students")
plt.title("Histogram of Marks")
plt.show()

# %%
from sympy import symbols, Eq, solve

x, y = symbols('x y')

eq1 = Eq(3*x + 5*y, 4)
eq2 = Eq(x - 5*y, 8)

solution = solve((eq1, eq2), (x, y))
print("Point of Intersection:", solution)
# Out:
# Point of Intersection: {x: 3, y: -1}

# %%
x, y =symbols('x, y')
L1 = Line(3*x+5*y-4)
L2= Line(x-5*y-8)
L1
# Out:
# Line2D(Point2D(0, 4/5), Point2D(1, 1/5))

# %%
L2
# Out:
# Line2D(Point2D(0, -8/5), Point2D(1, -7/5))

# %%
L1.intersection(L2)
# Out:
# [Point2D(3, -1)]

# %%
import matplotlib.pyplot as plt

subjects = ["History", "Geography", "English", "Sociology", "Psychology"]
students = [168, 90, 195, 95, 46]

plt.pie(students, labels=subjects, autopct='%1.1f%%', radius=0.7)
plt.title("Students Distribution")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, np.pi/2-0.1 , 50)  # avoid infinity at π/2
y = np.tan(x)

plt.plot(x, y, color='green')
plt.title("y = tan(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
x, y = symbols('x, y')
A = Point(7,2)
B = Point(3,-4)
L1 = Segment(A, B)
L2 = Line(2*x-y-1)
L1.angle_between(L2)
# Out:
# acos(-8*sqrt(65)/65)
